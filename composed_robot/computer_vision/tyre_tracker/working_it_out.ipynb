# %%
import numpy as np

# %%
contours = np.load('/home/gregorian/projects/composed-robot-desktop/computer_vision/tyre_tracker/contours.npy')
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 contours = np.load('/home/gregorian/projects/composed-robot-desktop/computer_vision/tyre_tracker/contours.npy')
#
# File ~/projects/composed-robot-desktop/venv/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:460, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     458 magic = fid.read(N)
#     459 if not magic:
# --> 460     raise EOFError("No data left in file")
#     461 # If the file size is less than N, we need to make sure not
#     462 # to seek past the beginning of the file
#     463 fid.seek(-min(N, len(magic)), 1)  # back-up
#
# EOFError: No data left in file

# %%
contour_sizes = np.array([300.0,700.25,30,1200,4000,5,10,400,500])

# %%
sorted_indexes = np.argsort(contour_sizes)
sorted_indexes
# Out:
# array([5, 6, 2, 0, 7, 8, 1, 3, 4])

# %%
contour_sizes_sorted = contour_sizes[sorted_indexes]
contour_sizes_sorted
# Out:
# array([4000, 1200,  700,  500,  400,  300,   30,   10,    5])

# %%
contour_sizes_sorted>200
# Out:
# array([ True,  True,  True,  True,  True,  True, False, False, False])

# %%
np.argmax((contour_sizes_sorted>200) & (contour_sizes_sorted<1000))
# Out:
# np.int64(3)

# %%
(contour_sizes_sorted>200) & (contour_sizes_sorted<1000)
# Out:
# array([False, False, False,  True,  True,  True,  True, False, False])

# %%
np.argmax([False,False])
# Out:
# np.int64(0)

# %%
np.array([False,False]).sum()
# Out:
# np.int64(0)
